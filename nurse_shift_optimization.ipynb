# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuji-Sakata0110/nurse_shift_optimization/blob/main/nurse_shift_optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 遺伝子最適化アルゴリズムでナースのシフト選びを最適化
#
# ## 参考
#
# ### 1. 遺伝的アルゴリズムでナーススケジューリング問題（シフト最適化）を解く
# https://qiita.com/shouta-dev/items/1970c2746c3c30f6b39e
#
# ### 2. 最適化アルゴリズムを実装していくぞ（遺伝的アルゴリズム）
# https://qiita.com/pocokhc/items/bca2b374b95c606e110f

# %%
import random

# 看護師の数
nurses_count = 5

# 1週間の日数
days_in_week = 7

# シフトの種類
shift_types = ['A', "P", 'N', 'R']

# 各看護師の希望シフト
nurse_preferences = {
    0: ['A', 'A', 'N', 'N', 'R', 'R', 'R'],
    1: ['N', 'N', 'A', 'A', 'A', 'N', 'R'],
    2: ['R', 'R', 'A', 'N', 'N', 'A', 'A'],
    3: ['A', 'A', 'A', 'N', 'N', 'N', 'R'],
    4: ['R', 'R', 'R', 'A', 'A', 'A', 'N']
}

# 適応度関数の定義 制約条件をこの関数で評価し、総合点を返却する （制約条件によって、スコアの重みを変更する）
def fitness_function(shift_schedule):
    total_fitness = 0
    for nurse_id, schedule in shift_schedule.items():
        # 連続する勤務日数の計算
        consecutive_days = 0
        for i in range(days_in_week - 1):
            if schedule[i] != 'R' and schedule[i] == schedule[i+1]:
                consecutive_days += 1
            else:
                consecutive_days = 0
            # 連続する勤務日数が多いほど適応度を減らす
            if consecutive_days > 2:
                total_fitness -= consecutive_days

        # 希望シフトとの一致度を計算
        for i in range(days_in_week):
            if schedule[i] == nurse_preferences[nurse_id][i]:
                total_fitness += 1

        # 週休2日であれば、スコアアップ
        if len([s for s in schedule if s == 'R']) == 2:
            total_fitness += 2

    return total_fitness

# 初期集団の生成 ナース5人の初期シフトの組み合わせを５０種類ランダムに準備する
def generate_initial_population():
    population = []
    for _ in range(population_size):
        schedule = {}
        for nurse_id in range(nurses_count):
            # ランダムなシフトの生成
            schedule[nurse_id] = [random.choice(shift_types) for _ in range(days_in_week)]
        population.append(schedule)
    return population

# 選択 ランダムに遺伝子を2つ選択し、スコアが高い方を交叉に回す
def selection(population):
    selected = []
    for _ in range(population_size):
        # ランダムに2つの個体を選択
        a, b = random.choices(population, k=2)
        selected.append(a if fitness_function(a) > fitness_function(b) else b)
    return selected

# 交叉 2つの遺伝子の中でランダムに要素を入れ替える。前半後半で分割。リストに追加して返却する。
def crossover(selected):
    offspring = []
    for i in range(0, len(selected), 2):
        parent1 = selected[i]
        parent2 = selected[i+1]
        crossover_point = random.randint(1, days_in_week - 1)
        child1 = {nurse_id: parent1[nurse_id][:crossover_point] + parent2[nurse_id][crossover_point:]
                  for nurse_id in range(nurses_count)}
        child2 = {nurse_id: parent2[nurse_id][:crossover_point] + parent1[nurse_id][crossover_point:]
                  for nurse_id in range(nurses_count)}

        offspring.extend([child1, child2])
    return offspring

# 突然変異 １０％の確率で突然変異が起き、要素の一部をランダムに変更する。局所的な最適解になることを避ける。
def mutation(offspring):
    mutated_offspring = []
    for schedule in offspring:
        if random.random() < mutation_rate:
            nurse_id = random.randint(0, nurses_count - 1)
            day = random.randint(0, days_in_week - 1)
            schedule[nurse_id][day] = random.choice(shift_types)
        mutated_offspring.append(schedule)
    return mutated_offspring

# アルゴリズムのパラメータ
population_size = 50
mutation_rate = 0.1
generations = 100

# 初期集団の生成
population = generate_initial_population()

# 最適な解の探索
for generation in range(generations):
    print(f"Generation {generation+1}/{generations}")

    # 選択
    selected = selection(population)

    # 交叉
    offspring = crossover(selected)

    # 突然変異
    mutated_offspring = mutation(offspring)

    # 新しい世代の生成
    population = mutated_offspring

    # 最良なスケジュールの表示
    best_schedule = max(population, key=fitness_function)
    print("Best schedule:", best_schedule)
    print("Fitness:", fitness_function(best_schedule))
    print()

# 最良なスケジュールの表示
best_schedule = max(population, key=fitness_function)
print("Final best schedule:", best_schedule)
print("Final fitness:", fitness_function(best_schedule))
# Out:
# Generation 1/100
# Best schedule: {0: ['A', 'A', 'N', 'N', 'A', 'R', 'A'], 1: ['N', 'N', 'N', 'A', 'N', 'R', 'R'], 2: ['A', 'R', 'A', 'N', 'R', 'A', 'N'], 3: ['A', 'R', 'A', 'R', 'A', 'P', 'R'], 4: ['R', 'R', 'R', 'R', 'R', 'P', 'A']}
# Fitness: 23
#
# Generation 2/100
# Best schedule: {0: ['A', 'A', 'N', 'N', 'A', 'R', 'R'], 1: ['N', 'N', 'N', 'A', 'N', 'R', 'R'], 2: ['A', 'R', 'A', 'N', 'R', 'A', 'P'], 3: ['A', 'R', 'A', 'R', 'A', 'P', 'P'], 4: ['R', 'R', 'R', 'R', 'R', 'P', 'P']}
# Fitness: 27
#
# Generation 3/100
# Best schedule: {0: ['A', 'A', 'N', 'N', 'A', 'R', 'P'], 1: ['N', 'N', 'N', 'A', 'N', 'P', 'A'], 2: ['A', 'R', 'A', 'N', 'R', 'A', 'N'], 3: ['A', 'R', 'A', 'R', 'A', 'P', 'A'], 4: ['R', 'R', 'R', 'R', 'R', 'P', 'A']}
# Fitness: 21
#
# Generation 4/100
# Best schedule: {0: ['A', 'A', 'N', 'N', 'R', 'A', 'R'], 1: ['N', 'N', 'N', 'A', 'R', 'P', 'P'], 2: ['A', 'R', 'A', 'N', 'R', 'A', 'N'], 3: ['A', 'R', 'A', 'R', 'A', 'P', 'A'], 4: ['R', 'R', 'R', 'R', 'R', 'N', 'A']}
# Fitness: 24
#
# Generation 5/100
# Best schedule: {0: ['A', 'A', 'N', 'N', 'A', 'R', 'A'], 1: ['N', 'N', 'N', 'P', 'P', 'P', 'R'], 2: ['A', 'R', 'A', 'P', 'P', 'R', 'P'], 3: ['A', 'R', 'A', 'N', 'A', 'N', 'R'], 4: ['R', 'R', 'R', 'A', 'A', 'N', 'R']}
# Fitness: 24
#
# Generation 6/100
# Best schedule: {0: ['A', 'A', 'N', 'N', 'N', 'R', 'A'], 1: ['N', 'N', 'N', 'P', 'R', 'P', 'R'], 2: ['A', 'R', 'A', 'P', 'N', 'R', 'P'], 3: ['A', 'R', 'A', 'N', 'N', 'N', 'R'], 4: ['R', 'R', 'R', 'A', 'N', 'N', 'R']}
# Fitness: 27
#
# Generation 7/100
# Best schedule: {0: ['N', 'A', 'N', 'N', 'N', 'R', 'A'], 1: ['N', 'N', 'N', 'P', 'R', 'P', 'R'], 2: ['A', 'R', 'A', 'P', 'N', 'R', 'P'], 3: ['A', 'R', 'A', 'N', 'N', 'N', 'R'], 4: ['R', 'R', 'R', 'A', 'N', 'N', 'R']}
# Fitness: 26
#
# Generation 8/100
# Best schedule: {0: ['A', 'A', 'A', 'N', 'N', 'R', 'A'], 1: ['N', 'N', 'N', 'P', 'R', 'P', 'R'], 2: ['A', 'R', 'A', 'P', 'N', 'R', 'P'], 3: ['A', 'R', 'A', 'N', 'N', 'N', 'R'], 4: ['R', 'R', 'R', 'A', 'N', 'N', 'R']}
# Fitness: 26
#
# Generation 9/100
# Best schedule: {0: ['A', 'A', 'A', 'N', 'N', 'R', 'A'], 1: ['N', 'N', 'N', 'P', 'R', 'P', 'R'], 2: ['A', 'R', 'A', 'P', 'N', 'R', 'P'], 3: ['A', 'R', 'A', 'N', 'N', 'N', 'R'], 4: ['R', 'R', 'R', 'A', 'N', 'N', 'R']}
# Fitness: 26
#
# Generation 10/100
# Best schedule: {0: ['A', 'R', 'P', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'P'], 3: ['P', 'A', 'N', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'N', 'A', 'N']}
# Fitness: 27
#
# Generation 11/100
# Best schedule: {0: ['A', 'R', 'P', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'P'], 3: ['P', 'A', 'N', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'N', 'A', 'N']}
# Fitness: 27
#
# Generation 12/100
# Best schedule: {0: ['A', 'R', 'P', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'P'], 3: ['P', 'A', 'N', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'N', 'A', 'N']}
# Fitness: 27
#
# Generation 13/100
# Best schedule: {0: ['A', 'R', 'P', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'P'], 3: ['P', 'A', 'N', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'N', 'A', 'N']}
# Fitness: 27
#
# Generation 14/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'P'], 3: ['P', 'A', 'N', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'N', 'A', 'N']}
# Fitness: 28
#
# Generation 15/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'P'], 3: ['P', 'A', 'N', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'N', 'A', 'N']}
# Fitness: 28
#
# Generation 16/100
# Best schedule: {0: ['A', 'R', 'P', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'P'], 3: ['P', 'A', 'N', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'N', 'A', 'N']}
# Fitness: 27
#
# Generation 17/100
# Best schedule: {0: ['A', 'R', 'P', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'P'], 3: ['P', 'A', 'N', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'N', 'A', 'N']}
# Fitness: 27
#
# Generation 18/100
# Best schedule: {0: ['A', 'R', 'P', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'N', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'N', 'A', 'N']}
# Fitness: 28
#
# Generation 19/100
# Best schedule: {0: ['A', 'R', 'P', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'N', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'N', 'A', 'N']}
# Fitness: 28
#
# Generation 20/100
# Best schedule: {0: ['A', 'R', 'P', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'N', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'N', 'A', 'N']}
# Fitness: 28
#
# Generation 21/100
# Best schedule: {0: ['A', 'R', 'P', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'N', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'N', 'A', 'N']}
# Fitness: 28
#
# Generation 22/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'N', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'N', 'A', 'N']}
# Fitness: 29
#
# Generation 23/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'N', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'N', 'A', 'N']}
# Fitness: 29
#
# Generation 24/100
# Best schedule: {0: ['A', 'R', 'P', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'N', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 29
#
# Generation 25/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'N', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 30
#
# Generation 26/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'N', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'N', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 30
#
# Generation 27/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'N', 'A', 'N']}
# Fitness: 30
#
# Generation 28/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'N', 'A', 'N']}
# Fitness: 30
#
# Generation 29/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'N', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 30
#
# Generation 30/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 31
#
# Generation 31/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 31
#
# Generation 32/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 31
#
# Generation 33/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 31
#
# Generation 34/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 31
#
# Generation 35/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 31
#
# Generation 36/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 31
#
# Generation 37/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 31
#
# Generation 38/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 31
#
# Generation 39/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 31
#
# Generation 40/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 31
#
# Generation 41/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['N', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 31
#
# Generation 42/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 31
#
# Generation 43/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['N', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 31
#
# Generation 44/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 31
#
# Generation 45/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['P', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 31
#
# Generation 46/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 47/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 48/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'A'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 49/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 50/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 51/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 52/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 53/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 54/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 55/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 56/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 57/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 58/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['P', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 59/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 60/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 61/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 62/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['P', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 63/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 64/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['P', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 65/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['P', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 66/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 67/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 68/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 69/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 70/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 71/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 72/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 73/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 74/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 75/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 76/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 77/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'A'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 78/100
# Best schedule: {0: ['A', 'R', 'N', 'A', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['N', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 32
#
# Generation 79/100
# Best schedule: {0: ['A', 'R', 'N', 'N', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 33
#
# Generation 80/100
# Best schedule: {0: ['A', 'R', 'N', 'N', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 33
#
# Generation 81/100
# Best schedule: {0: ['A', 'R', 'N', 'N', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 33
#
# Generation 82/100
# Best schedule: {0: ['A', 'R', 'N', 'N', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 33
#
# Generation 83/100
# Best schedule: {0: ['A', 'R', 'N', 'N', 'N', 'R', 'A'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 33
#
# Generation 84/100
# Best schedule: {0: ['A', 'R', 'N', 'N', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 33
#
# Generation 85/100
# Best schedule: {0: ['A', 'R', 'N', 'N', 'N', 'R', 'A'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 33
#
# Generation 86/100
# Best schedule: {0: ['A', 'R', 'N', 'N', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 33
#
# Generation 87/100
# Best schedule: {0: ['A', 'R', 'N', 'N', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 33
#
# Generation 88/100
# Best schedule: {0: ['A', 'R', 'N', 'N', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 33
#
# Generation 89/100
# Best schedule: {0: ['A', 'R', 'N', 'N', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['N', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 33
#
# Generation 90/100
# Best schedule: {0: ['A', 'R', 'N', 'N', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 33
#
# Generation 91/100
# Best schedule: {0: ['A', 'R', 'N', 'N', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['N', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 33
#
# Generation 92/100
# Best schedule: {0: ['A', 'R', 'N', 'N', 'P', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['P', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 33
#
# Generation 93/100
# Best schedule: {0: ['A', 'R', 'N', 'N', 'P', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['N', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 33
#
# Generation 94/100
# Best schedule: {0: ['A', 'R', 'N', 'N', 'P', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['N', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 33
#
# Generation 95/100
# Best schedule: {0: ['A', 'R', 'N', 'N', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['N', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 33
#
# Generation 96/100
# Best schedule: {0: ['A', 'R', 'N', 'N', 'P', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['N', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 33
#
# Generation 97/100
# Best schedule: {0: ['A', 'R', 'N', 'N', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['N', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 33
#
# Generation 98/100
# Best schedule: {0: ['A', 'R', 'N', 'N', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['N', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 33
#
# Generation 99/100
# Best schedule: {0: ['A', 'R', 'N', 'N', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['N', 'P', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 33
#
# Generation 100/100
# Best schedule: {0: ['A', 'R', 'N', 'N', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['N', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Fitness: 33
#
# Final best schedule: {0: ['A', 'R', 'N', 'N', 'N', 'R', 'P'], 1: ['R', 'N', 'A', 'A', 'R', 'N', 'P'], 2: ['N', 'A', 'R', 'N', 'N', 'R', 'A'], 3: ['A', 'A', 'A', 'R', 'N', 'N', 'R'], 4: ['A', 'R', 'R', 'A', 'A', 'A', 'N']}
# Final fitness: 33
